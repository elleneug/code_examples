# %%
#filter rdd and exclude all words starting from 'a' or 'c'

# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("FlatMap")
sc = SparkContext.getOrCreate(conf=conf)

# %%
rdd = sc.textFile('/FileStore/tables/filtering.txt')
rdd.collect()
# Out:
# Out[2]: ['this mango company animal',
#  'cat dog ant mic laptop',
#  'chair switch mobile am charger cover',
#  'amanda any alarm ant']

# %%
rdd2 = rdd.flatMap(lambda x: x.split(" "))
rdd2.collect()
# Out:
# Out[6]: ['this',
#  'mango',
#  'company',
#  'animal',
#  'cat',
#  'dog',
#  'ant',
#  'mic',
#  'laptop',
#  'chair',
#  'switch',
#  'mobile',
#  'am',
#  'charger',
#  'cover',
#  'amanda',
#  'any',
#  'alarm',
#  'ant']

# %%
def foo(x):
  if x.startswith('a') or x.startswith('c'):
    return False
  else:
    return True

rdd3 = rdd2.filter(foo)
rdd3.collect()
# Out:
# Out[10]: ['this', 'mango', 'dog', 'mic', 'laptop', 'switch', 'mobile']
