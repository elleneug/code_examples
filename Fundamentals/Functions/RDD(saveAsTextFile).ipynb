# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("saveAsTextFile")
sc = SparkContext.getOrCreate(conf=conf)

# %%
rdd = sc.textFile('/FileStore/tables/42_quiz-1.txt')
rdd2 = rdd.flatMap(lambda x: x.split(' '))
rdd3 = rdd2.map(lambda x: (x,1))

# %%
rdd3.saveAsTextFile('/FileStore/tables/output/sample_words_output2')

# %%
rdd.getNumPartitions()
# Out:
# Out[6]: 2

# %%
rdd.saveAsTextFile('/FileStore/tables/ouput/sample_words_output.txt')
