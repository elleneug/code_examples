# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("Average")
sc = SparkContext.getOrCreate(conf=conf)

# %%
rdd = sc.textFile('/FileStore/tables/movie_ratings.csv')
rdd.collect()
# Out:
# Out[3]: ['The Shawshank Redemption,3',
#  'The Matrix,5',
#  '12 Angry Men,3',
#  '12 Angry Men,4',
#  'The Matrix,5',
#  'Pulp Fiction,4',
#  'The Godfather,5',
#  'The Shawshank Redemption,2',
#  'Pulp Fiction,4',
#  'The Godfather,5',
#  '12 Angry Men,2',
#  'The Godfather,3',
#  'Pulp Fiction,4',
#  '12 Angry Men,1',
#  'The Shawshank Redemption,2',
#  '12 Angry Men,1',
#  'The Shawshank Redemption,5',
#  'Pulp Fiction,5',
#  'Pulp Fiction,2',
#  'The Matrix,4']

# %%
rdd2 = rdd.map(lambda x: (x.split(',')[0], (int(x.split(',')[1]),1)))
rdd2.collect()
# Out:
# Out[14]: [('The Shawshank Redemption', (3, 1)),
#  ('The Matrix', (5, 1)),
#  ('12 Angry Men', (3, 1)),
#  ('12 Angry Men', (4, 1)),
#  ('The Matrix', (5, 1)),
#  ('Pulp Fiction', (4, 1)),
#  ('The Godfather', (5, 1)),
#  ('The Shawshank Redemption', (2, 1)),
#  ('Pulp Fiction', (4, 1)),
#  ('The Godfather', (5, 1)),
#  ('12 Angry Men', (2, 1)),
#  ('The Godfather', (3, 1)),
#  ('Pulp Fiction', (4, 1)),
#  ('12 Angry Men', (1, 1)),
#  ('The Shawshank Redemption', (2, 1)),
#  ('12 Angry Men', (1, 1)),
#  ('The Shawshank Redemption', (5, 1)),
#  ('Pulp Fiction', (5, 1)),
#  ('Pulp Fiction', (2, 1)),
#  ('The Matrix', (4, 1))]

# %%
rdd3 = rdd2.reduceByKey(lambda x,y: (x[0]+y[0], x[1]+y[1]))
rdd3.collect()
# Out:
# Out[15]: [('The Shawshank Redemption', (12, 4)),
#  ('12 Angry Men', (11, 5)),
#  ('The Godfather', (13, 3)),
#  ('The Matrix', (14, 3)),
#  ('Pulp Fiction', (19, 5))]

# %%
rdd4 = rdd3.map(lambda x: (x[0],x[1][0]/x[1][1]))
rdd4.collect()
# Out:
# Out[16]: [('The Shawshank Redemption', 3.0),
#  ('12 Angry Men', 2.2),
#  ('The Godfather', 4.333333333333333),
#  ('The Matrix', 4.666666666666667),
#  ('Pulp Fiction', 3.8)]
