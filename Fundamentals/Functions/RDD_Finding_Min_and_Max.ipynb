# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("Min and Max")
sc = SparkContext.getOrCreate(conf=conf)

# %%
rdd = sc.textFile('/FileStore/tables/movie_ratings.csv')
rdd.collect()
# Out:
# Out[4]: ['The Shawshank Redemption,3',
#  'The Matrix,5',
#  '12 Angry Men,3',
#  '12 Angry Men,4',
#  'The Matrix,5',
#  'Pulp Fiction,4',
#  'The Godfather,5',
#  'The Shawshank Redemption,2',
#  'Pulp Fiction,4',
#  'The Godfather,5',
#  '12 Angry Men,2',
#  'The Godfather,3',
#  'Pulp Fiction,4',
#  '12 Angry Men,1',
#  'The Shawshank Redemption,2',
#  '12 Angry Men,1',
#  'The Shawshank Redemption,5',
#  'Pulp Fiction,5',
#  'Pulp Fiction,2',
#  'The Matrix,4']

# %%
x = 3
y = 4
x if x < y else y
# Out:
# Out[6]: 3

# %%
rdd2 = rdd.map(lambda x: (x.split(',')[0],int(x.split(',')[1])))
rdd2.collect()
# Out:
# Out[5]: [('The Shawshank Redemption', 3),
#  ('The Matrix', 5),
#  ('12 Angry Men', 3),
#  ('12 Angry Men', 4),
#  ('The Matrix', 5),
#  ('Pulp Fiction', 4),
#  ('The Godfather', 5),
#  ('The Shawshank Redemption', 2),
#  ('Pulp Fiction', 4),
#  ('The Godfather', 5),
#  ('12 Angry Men', 2),
#  ('The Godfather', 3),
#  ('Pulp Fiction', 4),
#  ('12 Angry Men', 1),
#  ('The Shawshank Redemption', 2),
#  ('12 Angry Men', 1),
#  ('The Shawshank Redemption', 5),
#  ('Pulp Fiction', 5),
#  ('Pulp Fiction', 2),
#  ('The Matrix', 4)]

# %%
rdd2.reduceByKey(lambda x , y : x if x < y else y).collect()
# Out:
# Out[7]: [('The Shawshank Redemption', 2),
#  ('12 Angry Men', 1),
#  ('The Godfather', 3),
#  ('The Matrix', 4),
#  ('Pulp Fiction', 2)]

# %%
rdd2.reduceByKey(lambda x , y : x if x > y else y).collect()
# Out:
# Out[8]: [('The Shawshank Redemption', 5),
#  ('12 Angry Men', 4),
#  ('The Godfather', 5),
#  ('The Matrix', 5),
#  ('Pulp Fiction', 5)]
