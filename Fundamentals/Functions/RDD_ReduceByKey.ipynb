# %%
from pyspark import SparkConf, SparkContext
conf = SparkConf().setAppName("distinct")
sc = SparkContext.getOrCreate(conf=conf)

# %%
rdd = sc.textFile('/FileStore/tables/doc-1.txt')
rdd.collect()
# Out:
# Out[2]: ['1 2 3 4 5', '3 4 5 66 77', '12 43 6 7 8', '12 12 33']

# %%
rdd2 = rdd.flatMap(lambda x: x.split(' '))

# %%
rdd2.collect()
# Out:
# Out[5]: ['1',
#  '2',
#  '3',
#  '4',
#  '5',
#  '3',
#  '4',
#  '5',
#  '66',
#  '77',
#  '12',
#  '43',
#  '6',
#  '7',
#  '8',
#  '12',
#  '12',
#  '33']

# %%
rdd3 = rdd2.map(lambda x: (x,1))
rdd3.collect()
# Out:
# Out[6]: [('1', 1),
#  ('2', 1),
#  ('3', 1),
#  ('4', 1),
#  ('5', 1),
#  ('3', 1),
#  ('4', 1),
#  ('5', 1),
#  ('66', 1),
#  ('77', 1),
#  ('12', 1),
#  ('43', 1),
#  ('6', 1),
#  ('7', 1),
#  ('8', 1),
#  ('12', 1),
#  ('12', 1),
#  ('33', 1)]

# %%
rdd3.reduceByKey(lambda x,y: x+y).collect()
# Out:
# Out[7]: [('1', 1),
#  ('4', 2),
#  ('66', 1),
#  ('77', 1),
#  ('12', 3),
#  ('8', 1),
#  ('33', 1),
#  ('2', 1),
#  ('3', 2),
#  ('5', 2),
#  ('43', 1),
#  ('6', 1),
#  ('7', 1)]
