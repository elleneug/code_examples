# %%
from kedro.framework.context import KedroContext

# %%
load_context("../")
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 load_context("../")                                                                          │
# │   2                                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# NameError: name 'load_context' is not defined

# %%
from kedro.framework.context import KedroContext
from kedro.framework.session import KedroSession
from kedro.framework.startup import bootstrap_project

# %%
with KedroSession.create("project", env="env1") as session:
    context = session.load_context()
    catalog = context.catalog
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 with KedroSession.create("project", env="env1") as session:                                  │
# │   2 │   context = session.load_context()                                                         │
# │   3 │   catalog = context.catalog                                                                │
# │   4                                                                                              │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/kedro/framework/session/session. │
# │ py:191 in create                                                                                 │
# │                                                                                                  │
# │   188 │   │   session._store.update(session_data)                                                │
# │   189 │   │                                                                                      │
# │   190 │   │   # we need a ConfigLoader registered in order to be able to set up logging          │
# │ ❱ 191 │   │   session._setup_logging()                                                           │
# │   192 │   │   return session                                                                     │
# │   193 │                                                                                          │
# │   194 │   def _get_logging_config(self) -> Dict[str, Any]:                                       │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/kedro/framework/session/session. │
# │ py:208 in _setup_logging                                                                         │
# │                                                                                                  │
# │   205 │   def _setup_logging(self) -> None:                                                      │
# │   206 │   │   """Register logging specified in logging directory."""                             │
# │   207 │   │   try:                                                                               │
# │ ❱ 208 │   │   │   logging_config = self._get_logging_config()                                    │
# │   209 │   │   except MissingConfigException:                                                     │
# │   210 │   │   │   self._logger.debug(                                                            │
# │   211 │   │   │   │   "No project logging configuration loaded; "                                │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/kedro/framework/session/session. │
# │ py:195 in _get_logging_config                                                                    │
# │                                                                                                  │
# │   192 │   │   return session                                                                     │
# │   193 │                                                                                          │
# │   194 │   def _get_logging_config(self) -> Dict[str, Any]:                                       │
# │ ❱ 195 │   │   logging_config = self._get_config_loader()["logging"]                              │
# │   196 │   │   if isinstance(logging_config, omegaconf.DictConfig):                               │
# │   197 │   │   │   logging_config = OmegaConf.to_container(logging_config)                        │
# │   198 │   │   # turn relative paths in logging config into absolute path                         │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/kedro/config/config.py:115 in    │
# │ __getitem__                                                                                      │
# │                                                                                                  │
# │   112 │   │   # explicitly on the ``ConfigLoader`` instance.                                     │
# │   113 │   │   if key in self:                                                                    │
# │   114 │   │   │   return super().__getitem__(key)                                                │
# │ ❱ 115 │   │   return self.get(*self.config_patterns[key])                                        │
# │   116 │                                                                                          │
# │   117 │   def __repr__(self):  # pragma: no cover                                                │
# │   118 │   │   return (                                                                           │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/kedro/config/config.py:129 in    │
# │ get                                                                                              │
# │                                                                                                  │
# │   126 │   │   return _remove_duplicates(self._build_conf_paths())                                │
# │   127 │                                                                                          │
# │   128 │   def get(self, *patterns: str) -> Dict[str, Any]:  # type: ignore                       │
# │ ❱ 129 │   │   return _get_config_from_patterns(                                                  │
# │   130 │   │   │   conf_paths=self.conf_paths, patterns=list(patterns)                            │
# │   131 │   │   )                                                                                  │
# │   132                                                                                            │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/kedro/config/common.py:72 in     │
# │ _get_config_from_patterns                                                                        │
# │                                                                                                  │
# │    69 │                                                                                          │
# │    70 │   for conf_path in conf_paths:                                                           │
# │    71 │   │   if not Path(conf_path).is_dir():                                                   │
# │ ❱  72 │   │   │   raise ValueError(                                                              │
# │    73 │   │   │   │   f"Given configuration path either does not exist "                         │
# │    74 │   │   │   │   f"or is not a valid directory: {conf_path}"                                │
# │    75 │   │   │   )                                                                              │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: Given configuration path either does not exist or is not a valid directory:
# /Users/Elena_Sidorova/Library/CloudStorage/OneDrive-McKinsey&Company/Desktop/Basics/sg-api/notebooks/conf/base

# %%
catalog.list()
# Out:
# ['raw_temp',
#  'temp_plot',
#  'station_temperature',
#  'downloaded_station_data',
#  'already_downloaded_dates',
#  'already_downloaded_dates!',
#  'parameters',
#  'params:station_id',
#  'params:start_date',
#  'params:end_date']

# %%
# %reload kedro
# Out:
# UsageError: Line magic function `%reload` not found.

# %%
# %run '{}'
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/IPython/core/magics/execution.py │
# │ :714 in run                                                                                      │
# │                                                                                                  │
# │    711 │   │   try:                                                                              │
# │    712 │   │   │   fpath = None # initialize to make sure fpath is in scope later                │
# │    713 │   │   │   fpath = arg_lst[0]                                                            │
# │ ❱  714 │   │   │   filename = file_finder(fpath)                                                 │
# │    715 │   │   except IndexError:                                                                │
# │    716 │   │   │   msg = 'you must provide at least a filename.'                                 │
# │    717 │   │   │   raise Exception(msg)                                                          │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/IPython/utils/path.py:109 in     │
# │ get_py_filename                                                                                  │
# │                                                                                                  │
# │   106 │   if os.path.isfile(name):                                                               │
# │   107 │   │   return name                                                                        │
# │   108 │   else:                                                                                  │
# │ ❱ 109 │   │   raise IOError('File `%r` not found.' % name)                                       │
# │   110                                                                                            │
# │   111                                                                                            │
# │   112 def filefind(filename, path_dirs=None):                                                    │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# OSError: File `'{}.py'` not found.
#
# During handling of the above exception, another exception occurred:
#
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:1                                                                                    │
# │                                                                                                  │
# │ ❱ 1 get_ipython().run_line_magic('run', "'{}'")                                                  │
# │   2                                                                                              │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/IPython/core/interactiveshell.py │
# │ :2364 in run_line_magic                                                                          │
# │                                                                                                  │
# │   2361 │   │   │   if getattr(fn, "needs_local_scope", False):                                   │
# │   2362 │   │   │   │   kwargs['local_ns'] = self.get_local_scope(stack_depth)                    │
# │   2363 │   │   │   with self.builtin_trap:                                                       │
# │ ❱ 2364 │   │   │   │   result = fn(*args, **kwargs)                                              │
# │   2365 │   │   │   return result                                                                 │
# │   2366 │                                                                                         │
# │   2367 │   def get_local_scope(self, stack_depth):                                               │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/decorator.py:232 in fun          │
# │                                                                                                  │
# │   229 │   │   def fun(*args, **kw):                                                              │
# │   230 │   │   │   if not kwsyntax:                                                               │
# │   231 │   │   │   │   args, kw = fix(args, kw, sig)                                              │
# │ ❱ 232 │   │   │   return caller(func, *(extras + args), **kw)                                    │
# │   233 │   fun.__name__ = func.__name__                                                           │
# │   234 │   fun.__doc__ = func.__doc__                                                             │
# │   235 │   fun.__wrapped__ = func                                                                 │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/IPython/core/magic.py:187 in     │
# │ <lambda>                                                                                         │
# │                                                                                                  │
# │   184 │   # This is a closure to capture the magic_kind.  We could also use a class,             │
# │   185 │   # but it's overkill for just that one bit of state.                                    │
# │   186 │   def magic_deco(arg):                                                                   │
# │ ❱ 187 │   │   call = lambda f, *a, **k: f(*a, **k)                                               │
# │   188 │   │                                                                                      │
# │   189 │   │   if callable(arg):                                                                  │
# │   190 │   │   │   # "Naked" decorator call (just @foo, no args)                                  │
# │                                                                                                  │
# │ /Users/Elena_Sidorova/opt/anaconda3/lib/python3.9/site-packages/IPython/core/magics/execution.py │
# │ :725 in run                                                                                      │
# │                                                                                                  │
# │    722 │   │   │   │   msg = e.message                                                           │
# │    723 │   │   │   if os.name == 'nt' and re.match(r"^'.*'$",fpath):                             │
# │    724 │   │   │   │   warn('For Windows, use double quotes to wrap a filename: %run "mypath\\m  │
# │ ❱  725 │   │   │   raise Exception(msg)                                                          │
# │    726 │   │   except TypeError:                                                                 │
# │    727 │   │   │   if fpath in sys.meta_path:                                                    │
# │    728 │   │   │   │   filename = ""                                                             │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# Exception: File `'{}.py'` not found.

# %%
# !ls -a /..
# Out:
# .                Library          dev              tmp
# ..               System           etc              usr
# .VolumeIcon.icns Users            home             var
# .file            Volumes          opt
# .vol             bin              private
# Applications     cores            sbin
